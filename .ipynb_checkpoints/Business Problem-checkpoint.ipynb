# %% [markdown]
# # PNEUMONIA DETECTION USING CHEST X-RAY IMAGES

# %% [markdown]
# ## Problem Statement
#
# Pneumonia is a respiratory disease that causes inflammation in one or both lungs, resulting in symptoms such as cough, fever, and difficulty breathing. Early detection of pneumonia is essential for effective treatment and improved patient outcomes. It accounts for more than 15% of deaths in children under the age of five years. Therefore, early diagnosis and management can play a pivotal role in preventing the disease from becoming fatal.
# In acute respiratory diseases, human lungs are made up of small sacs called alveoli, which are normally in the air in healthy individuals. However, in pneumonia, these alveoli get filled with fluid or "pus." One of the major steps in phenomena detection and treatment is obtaining the chest X-ray (CXR). Physicians use this X-ray image to diagnose or monitor treatment for pneumonia conditions. This type of chest X-ray is also used in the diagnosis of diseases like emphysema, lung cancer, line and tube placement, and tuberculosis.
# Moreover, there is significant variability in the way chest X-ray images are acquired and processed, which can impact the quality and consistency of the images. This variability can make it challenging to develop robust algorithms that can accurately identify pneumonia in all types of images. Hence, there is a need to develop robust, data-driven algorithms that are trained on large, high-quality datasets and validated using a range of imaging techniques and expert radiological analysis.

# %% [markdown]
# ## Main Objectives
# 1.	Research, design, and implement advanced algorithms for the accurate detection of pneumonia in chest X-ray images.
# 2.	Construct a robust binary classifier capable of distinguishing between normal and pneumonia cases in chest X-ray images.
# 3.	Integrate the developed pneumonia detection algorithms into an automated diagnostic tool for chest X-ray images.
# 4.	Improve the efficiency and precision of pneumonia diagnosis by deploying the automated diagnostic tool.

# %% [markdown]
# ## Specific Objective
# The goal of this project is to develop an automated system for detecting and classifying pneumonia in medical images.
# Design and implement a robust deep learning algorithm, for detecting and classifying pneumonia in chest X-ray images.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# The dataset, sourced from Kaggle and accessible at https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia/data , is organized into three main folders: train, test, and val. Each folder includes subfolders representing two distinct image categories: Pneumonia and Normal. The dataset comprises a total of 5,856 chest X-ray images in JPEG format. These images, employing the anterior-posterior technique, originate from retrospective cohorts of pediatric patients aged one to five years at the Guangzhou Women and Children’s Medical Center in Guangzhou, China. The inclusion of these chest X-ray images in the dataset was part of routine clinical care for pediatric patients.
#
# Ensuring dataset quality, an initial screening process eliminated low-quality or unreadable scans to minimize errors. Two expert physicians then meticulously graded the diagnoses associated with the images, deeming them suitable for training the AI system only after this rigorous evaluation. To further mitigate potential grading errors, an additional layer of scrutiny was applied to the evaluation set. This involved examination by a third expert, providing an extra level of assurance to the accuracy of the diagnoses. This comprehensive approach to quality control and grading establishes a robust foundation for the analysis of chest X-ray images, enhancing the reliability of the AI system trained on this dataset.

# %% [markdown]
# ### Importing libraries

# %%
# Import libraries
import os
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
import opendatasets as od

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
import random
from pathlib import Path #to be able to use functions using path
from collections import Counter

# Data science tools
import pandas as pd # data processing
import numpy as np # linear algebra

# Tensorflow for GPU
import tensorflow as tf
from tensorflow.compat.v1 import Session, ConfigProto, set_random_seed
from tensorflow.python.client import device_lib

# Keras library for Modeling
import keras
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.layers import Conv2D, MaxPool2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.callbacks import ReduceLROnPlateau
from keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.constraints import max_norm
#import tensorflow.contrib.keras as keras
from keras import backend as K

# OpenCV
import cv2

# Resize images
from skimage.io import imread
from skimage.transform import resize

# Scikit-learn library
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# Visualizations
from PIL import Image
import imgaug as aug
import imgaug.augmenters as iaa
import matplotlib.pyplot as plt
import matplotlib.image as mimg # images
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Loading Data
#
# The initial step involves loading the dataset of chest X-ray images, each labelled with annotations indicating the presence of pneumonia or normal conditions. Following this, we standardise the size of all images to ensure uniformity.

# %%
import os

# Get the current working directory
current_dir = os.getcwd()

# Define the relative path to the dataset within the GitHub repository
relative_dataset_path = 'chest_xray'

# Construct the full path to the dataset
dataset_path = os.path.join(current_dir, relative_dataset_path)

# Define the data directories
train_data_folder = os.path.join(dataset_path, 'train')
test_data_folder = os.path.join(dataset_path, 'test')
val_data_folder = os.path.join(dataset_path, 'val')


# Loading and resizing images
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150

def get_training_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            img_path = os.path.join(path, img)
            img_arr = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img_arr is not None:
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            else:
                print(f"Error loading image: {img_path}")
    return np.array(data, dtype=object)

# loading data
train_data = get_training_data(train_data_folder)
test_data = get_training_data(test_data_folder)
val_data = get_training_data(val_data_folder)

# %% [markdown]
# We then determine the quantity of images in the training, testing and validation sets.

# %%
# Function to count the number of image files in a folder
def count_images_in_folder(folder):
    return len([f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))])

# Count the number of images in each dataset
train_images = count_images_in_folder(os.path.join(train_data_folder, 'PNEUMONIA')) + \
                count_images_in_folder(os.path.join(train_data_folder, 'NORMAL'))

test_images = count_images_in_folder(os.path.join(test_data_folder, 'PNEUMONIA')) + \
               count_images_in_folder(os.path.join(test_data_folder, 'NORMAL'))

val_images = count_images_in_folder(os.path.join(val_data_folder, 'PNEUMONIA')) + \
              count_images_in_folder(os.path.join(val_data_folder, 'NORMAL'))

# Display the counts
print(f"Number of images in the training set: {train_images}")
print(f"Number of images in the testing set: {test_images}")
print(f"Number of images in the validation set: {val_images}")
# Out:
# Number of images in the training set: 5216
# Number of images in the testing set: 624
# Number of images in the validation set: 16

# %% [markdown]
# We check and print the count of files in the different sub-folders corresponding to the specified labels for the training, validation, and test sets.

# %%
def count_file(dir=None, labels=None):
  for label in labels:
    num_data= len(os.listdir(os.path.join(dir, label)))
    print(f'Count of {label} : {num_data}')
    
labels= ['PNEUMONIA','NORMAL']
print('Train Set: \n' + '='*50)
count_file(train_data_folder,labels)

print('\nValidation Set: \n' + '='*50)
count_file(val_data_folder,labels)

print('\nTest Set: \n' + '='*50)
count_file(test_data_folder,labels)
# Out:
# Train Set:
# ==================================================
# Count of PNEUMONIA : 3875
# Count of NORMAL : 1341
#
# Validation Set:
# ==================================================
# Count of PNEUMONIA : 8
# Count of NORMAL : 8
#
# Test Set:
# ==================================================
# Count of PNEUMONIA : 390
# Count of NORMAL : 234

# %% [markdown]
# ### Data Inspection
#
# Then we validate for corrupt files: It is crucial to identify and eliminate corrupt images as they can lead to errors during the model training or introduce biases.

# %%
# Check for corrupt files and remove them if any.

def check_for_corrupt_files(directory):
    corrupt_files = []
    for subdir, dirs, files in os.walk(directory):
        for file in files:
            filepath = os.path.join(subdir, file)
            try:
                with Image.open(filepath) as img:
                    img.verify()  
            except (IOError, SyntaxError) as e:
                corrupt_files.append(filepath)

    return corrupt_files

directory = 'chest_xray'  
corrupt_files = check_for_corrupt_files(directory)

if corrupt_files:
    print("Found corrupt or unreadable files:")
    for file in corrupt_files:
        print(file)
else:
    print("No corrupt files found.")
# Out:
# No corrupt files found.

# %% [markdown]
# Image Quality Assessment: Manually review a subset of images allowing for an evaluation of their quality in terms of focus, lighting, and clarity. Images of low quality may adversely affect the model's learning process.

# %%
# Check the quality of the images
def check_image_quality(directory, threshold=0.05):
    """
    Checks for images that are too dark or too bright, indicating potential quality issues.
    :param directory: Directory containing the image dataset.
    :param threshold: Fraction of pixels that are either black or white to consider the image as poor quality.
    """
    for subdir, dirs, files in os.walk(directory):
        for file in files:
            filepath = os.path.join(subdir, file)
            try:
                with Image.open(filepath) as img:
                    img_array = np.array(img)
                    # Check if the image is grayscale or colored
                    if len(img_array.shape) == 2 or img_array.shape[2] == 1:  # Grayscale image
                        n_white = np.sum(img_array >= 255)
                        n_black = np.sum(img_array <= 0)
                    else:  # Colored image
                        n_white = np.sum(np.all(img_array >= [255, 255, 255], axis=2))
                        n_black = np.sum(np.all(img_array <= [0, 0, 0], axis=2))

                    # Check if the image has too many black or white pixels
                    if (n_white + n_black) / img_array.size > threshold:
                        print(f'Image {file} in {subdir} might be of poor quality')
            except IOError:
                # This can catch errors in opening the image file
                print(f'Error opening {file} in {subdir}')

check_image_quality('chest_xray')
# Out:
# Image IM-0070-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0071-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0073-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0075-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0083-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0086-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0087-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0099-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0101-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0102-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image IM-0107-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0007-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0012-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0013-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0019-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0023-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0027-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0029-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0035-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0041-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0045-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0051-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0052-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0058-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0059-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0060-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0066-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0072-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0092-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0098-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0102-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0105-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0107-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0110-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0111-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0112-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0117-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0120-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0123-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0129-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0130-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0131-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0132-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0135-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0139-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0141-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0145-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0146-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0150-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0195-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0199-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0201-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0206-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0210-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0217-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0219-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0221-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0222-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0229-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0232-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0233-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0238-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0246-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0249-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0252-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0256-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0267-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0272-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0273-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0274-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0275-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0278-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0279-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0280-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0281-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0285-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0287-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0288-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0294-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0297-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0301-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0302-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0303-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0304-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0305-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0307-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0309-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0311-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0312-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0313-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0315-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0316-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0317-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0319-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0321-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0322-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0323-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0325-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0326-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0327-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0328-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0330-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0331-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0333-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0335-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0336-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0337-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0338-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0339-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0340-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0343-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0345-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0346-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0347-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0348-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0350-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0351-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0352-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0353-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0354-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0357-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0359-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0362-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0364-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0366-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0368-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0369-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0370-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0372-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0373-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0374-0001-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0374-0001-0002.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0374-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0376-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0378-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image NORMAL2-IM-0380-0001.jpeg in chest_xray\test\NORMAL might be of poor quality
# Image person100_bacteria_475.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person103_bacteria_490.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person108_bacteria_511.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person109_bacteria_522.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person109_bacteria_528.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person111_bacteria_537.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person113_bacteria_543.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person117_bacteria_557.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person119_bacteria_567.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person119_bacteria_568.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person120_bacteria_573.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person121_bacteria_580.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person122_bacteria_581.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person124_bacteria_592.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person127_bacteria_604.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person128_bacteria_608.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person130_bacteria_623.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person130_bacteria_628.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person136_bacteria_648.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person136_bacteria_654.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person139_bacteria_666.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person140_bacteria_668.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person143_bacteria_689.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person146_bacteria_704.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person147_bacteria_711.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person150_bacteria_717.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person152_bacteria_724.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person153_bacteria_726.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person154_bacteria_728.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person157_bacteria_740.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person158_bacteria_745.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person15_virus_46.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1612_virus_2797.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1612_virus_2798.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1613_virus_2799.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person161_bacteria_762.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1620_virus_2807.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1622_virus_2810.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1625_virus_2817.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1627_virus_2819.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1628_virus_2821.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1628_virus_2822.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1629_virus_2823.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1631_virus_2826.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1632_virus_2827.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1633_virus_2829.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1634_virus_2830.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1635_virus_2831.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1637_virus_2834.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1640_virus_2839.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1641_virus_2840.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1642_virus_2842.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1644_virus_2844.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1645_virus_2845.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1647_virus_2848.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1649_virus_2850.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1650_virus_2852.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1650_virus_2854.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1651_virus_2855.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1653_virus_2858.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1653_virus_2859.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1657_virus_2864.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1659_virus_2867.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1660_virus_2869.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1662_virus_2875.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1663_virus_2876.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1664_virus_2877.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1667_virus_2881.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1668_virus_2882.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1669_virus_2884.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1669_virus_2885.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1670_virus_2886.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1671_virus_2887.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1673_virus_2889.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1674_virus_2890.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1675_virus_2891.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1678_virus_2895.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1679_virus_2896.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1680_virus_2897.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person172_bacteria_828.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person173_bacteria_831.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person18_virus_49.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person19_virus_50.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person1_virus_13.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person22_virus_54.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person23_virus_56.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person25_virus_59.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person26_virus_60.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person28_virus_62.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person28_virus_63.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person29_virus_64.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person32_virus_71.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person33_virus_72.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person35_virus_80.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person36_virus_81.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person37_virus_82.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person38_virus_84.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person39_virus_85.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person40_virus_87.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person41_virus_88.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person42_virus_89.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person43_virus_92.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person44_virus_94.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person45_virus_95.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person46_virus_96.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person47_virus_99.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person49_virus_101.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person50_virus_102.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person53_virus_107.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person53_virus_108.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person55_virus_110.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person56_virus_112.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person57_virus_113.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person59_virus_116.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person61_virus_118.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person62_virus_119.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person63_virus_121.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person64_virus_122.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person65_virus_123.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person69_virus_129.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person70_virus_130.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person71_virus_131.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person71_virus_132.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person74_virus_135.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person76_virus_138.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person78_bacteria_387.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person78_virus_140.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person80_bacteria_393.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person83_bacteria_407.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person88_bacteria_439.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person91_bacteria_445.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person91_bacteria_448.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person91_bacteria_449.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image person99_bacteria_474.jpeg in chest_xray\test\PNEUMONIA might be of poor quality
# Image IM-0117-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0119-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0125-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0127-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0128-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0129-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0131-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0133-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0135-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0141-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0143-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0145-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0147-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0149-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0151-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0154-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0156-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0158-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0162-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0166-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0168-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0177-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0178-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0182-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0183-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0185-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0187-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0189-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0191-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0193-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0199-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0201-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0203-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0205-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0206-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0207-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0210-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0213-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0215-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0216-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0219-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0220-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0222-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0223-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0226-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0227-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0228-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0229-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0230-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0234-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0236-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0237-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0238-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0239-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0240-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0241-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0244-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0245-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0248-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0251-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0253-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0255-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0256-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0264-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0265-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0266-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0270-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0273-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0276-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0278-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0279-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0280-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0282-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0283-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0285-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0289-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0290-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0291-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0293-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0295-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0300-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0301-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0303-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0304-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0305-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0309-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0311-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0312-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0313-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0314-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0316-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0317-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0318-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0320-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0325-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0326-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0331-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0335-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0338-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0340-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0341-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0346-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0347-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0349-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0350-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0351-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0354-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0356-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0357-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0358-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0362-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0363-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0364-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0365-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0367-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0368-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0370-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0372-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0374-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0375-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0377-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0379-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0381-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0382-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0384-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0385-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0387-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0388-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0391-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0392-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0393-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0394-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0400-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0404-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0410-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0411-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0414-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0417-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0419-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0421-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0424-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0425-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0427-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0428-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0429-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0429-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0429-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0430-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0431-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0432-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0433-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0435-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0435-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0437-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0437-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0438-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0439-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0439-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0439-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0440-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0441-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0442-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0444-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0445-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0446-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0447-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0448-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0449-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0450-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0451-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0452-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0453-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0453-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0457-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0458-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0459-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0460-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0461-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0464-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0465-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0467-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0467-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0467-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0469-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0473-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0474-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0475-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0476-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0477-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0478-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0479-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0480-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0481-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0483-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0484-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0486-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0487-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0488-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0490-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0491-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0491-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0491-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0492-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0493-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0495-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0497-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0497-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0499-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0500-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0501-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0501-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0501-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0502-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0503-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0504-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0505-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0505-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0505-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0507-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0508-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0509-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0509-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0509-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0510-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0511-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0511-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0512-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0513-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0514-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0515-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0516-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0517-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0517-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0519-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0519-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0520-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0521-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0522-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0523-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0523-0001-0003.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0523-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0524-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0525-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0525-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0526-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0527-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0528-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0530-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0531-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0532-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0533-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0533-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0533-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0534-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0535-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0536-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0537-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0538-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0539-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0539-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0540-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0541-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0542-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0543-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0543-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0544-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0545-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0545-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0545-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0546-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0548-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0549-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0549-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0549-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0551-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0551-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0552-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0553-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0553-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0553-0001-0003.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0553-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0554-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0555-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0555-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0555-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0556-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0557-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0559-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0560-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0561-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0562-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0563-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0565-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0566-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0569-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0570-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0571-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0575-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0577-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0578-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0579-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0580-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0582-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0583-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0584-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0588-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0591-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0592-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0593-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0595-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0596-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0598-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0599-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0600-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0601-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0602-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0604-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0605-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0606-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0607-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0608-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0608-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0609-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0612-0001-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0612-0001-0002.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0612-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0613-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0614-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# Image IM-0615-0001.jpeg in chest_xray\train\NORMAL might be of poor quality
# ...
# Image person659_virus_1243.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person660_virus_1244.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person663_bacteria_2555.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person664_virus_1249.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person665_virus_1250.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person667_virus_1252.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person667_virus_1253.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person66_bacteria_326.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person672_virus_1261.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person674_bacteria_2568.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person677_virus_1268.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person678_bacteria_2572.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person679_virus_1270.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person67_bacteria_334.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person681_bacteria_2576.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person687_bacteria_2583.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person68_bacteria_337.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person700_bacteria_2599.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person701_bacteria_2600.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person701_virus_1297.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person702_virus_1299.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person703_virus_1300.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person706_virus_1304.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person707_virus_1305.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person70_bacteria_346.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person710_bacteria_2611.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person718_bacteria_2620.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person71_bacteria_351.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person721_virus_1340.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person722_virus_1341.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person723_virus_1342.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person727_bacteria_2629.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person727_virus_1347.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person72_bacteria_354.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person730_virus_1351.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person731_virus_1352.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person732_virus_1353.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person735_bacteria_2638.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person735_virus_1356.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person744_bacteria_2647.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person746_bacteria_2649.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person74_bacteria_363.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person752_virus_1377.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person75_bacteria_369.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person765_bacteria_2669.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person765_virus_1393.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person76_bacteria_372.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person776_virus_1405.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person779_bacteria_2683.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person780_bacteria_2684.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person781_virus_1412.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person783_bacteria_2687.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person787_bacteria_2691.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person790_virus_1421.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person791_virus_1422.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person794_bacteria_2700.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person798_virus_1430.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person801_virus_1434.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person802_bacteria_2708.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person803_virus_1436.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person805_bacteria_2712.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person808_bacteria_2716.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person808_virus_1442.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person80_virus_150.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person811_bacteria_2721.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person811_virus_1447.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person815_bacteria_2726.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person81_virus_152.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person81_virus_153.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person82_virus_154.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person82_virus_155.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person833_virus_1469.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person83_virus_156.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person840_bacteria_2759.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person841_virus_1481.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person844_virus_1487.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person846_bacteria_2766.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person846_virus_1491.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person848_virus_1493.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person849_virus_1494.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person852_virus_1497.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person853_virus_1498.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person855_virus_1500.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person859_virus_1504.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person860_virus_1505.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person861_virus_1506.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person863_virus_1508.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person864_virus_1509.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person867_virus_1512.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person868_virus_1513.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person86_virus_159.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person870_virus_1516.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person871_bacteria_2793.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person871_virus_1517.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person877_virus_1525.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person878_bacteria_2801.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person878_virus_1526.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person880_virus_1529.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person881_virus_1531.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person883_virus_1533.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person884_bacteria_2808.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person884_virus_1534.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person885_bacteria_2809.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person886_bacteria_2810.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person888_virus_1538.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person890_virus_1540.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person891_virus_1541.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person894_virus_1546.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person895_virus_1547.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person896_virus_1548.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person898_virus_1552.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person899_virus_1553.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person89_virus_168.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person8_bacteria_37.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person900_virus_1554.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person901_virus_1555.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person905_virus_1561.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person907_virus_1563.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person908_virus_1564.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person911_virus_1567.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person913_virus_1570.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person914_virus_1571.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person915_virus_1572.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person919_bacteria_2844.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person919_virus_1576.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person920_bacteria_2845.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person924_virus_1581.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person925_virus_1582.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person931_virus_1592.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person932_virus_1593.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person933_virus_1594.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person936_virus_1598.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person940_virus_1602.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person941_virus_1610.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person943_bacteria_2868.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person945_virus_1616.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person946_bacteria_2871.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person94_virus_176.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person950_virus_1621.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person951_virus_1622.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person952_virus_1623.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person955_virus_1627.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person958_virus_1630.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person95_virus_177.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person962_virus_1635.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person964_virus_1637.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person966_virus_1639.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person967_virus_1640.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person969_bacteria_2894.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person970_bacteria_2895.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person970_virus_1644.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person972_bacteria_2897.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person972_virus_1646.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person974_virus_1649.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person976_virus_1651.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person977_bacteria_2902.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person978_virus_1653.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person979_bacteria_2905.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person980_bacteria_2906.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person981_virus_1657.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person982_virus_1658.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person983_bacteria_2910.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person983_virus_1660.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person988_bacteria_2915.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person988_virus_1666.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person989_virus_1667.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person990_bacteria_2917.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person991_virus_1669.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person992_virus_1670.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person993_virus_1671.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person995_virus_1676.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person997_virus_1678.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image person99_virus_183.jpeg in chest_xray\train\PNEUMONIA might be of poor quality
# Image NORMAL2-IM-1427-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image NORMAL2-IM-1430-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image NORMAL2-IM-1431-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image NORMAL2-IM-1436-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image NORMAL2-IM-1438-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image NORMAL2-IM-1440-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image NORMAL2-IM-1442-0001.jpeg in chest_xray\val\NORMAL might be of poor quality
# Image person1947_bacteria_4876.jpeg in chest_xray\val\PNEUMONIA might be of poor quality
# Image person1954_bacteria_4886.jpeg in chest_xray\val\PNEUMONIA might be of poor quality

# %% [markdown]
# ### Data Cleaning
#
# Detecting whether an image is blurred based on the variance of the Laplacian. This is a common technique to identify blurred images in image processing applications.

# %%
# Check for blurred images

def is_blurred(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    fm = cv2.Laplacian(gray, cv2.CV_64F).var()
    return fm < 100  # threshold for blurriness; adjust as needed

# %% [markdown]
# We need the images to have a consistent size for further analysis or model input. So we adjust the desired_size parameter according to our requirements.

# %%
# Resizing the images while maintaining their original aspect ratio
def normalize_aspect_ratio(image_path, desired_size=224):
    image = Image.open(image_path)
    old_size = image.size

    ratio = float(desired_size) / max(old_size)
    new_size = tuple([int(x * ratio) for x in old_size])
    image = image.resize(new_size, Image.ANTIALIAS)

    new_im = Image.new("RGB", (desired_size, desired_size))
    new_im.paste(image, ((desired_size - new_size[0]) // 2,
                        (desired_size - new_size[1]) // 2))

    return new_im

# %% [markdown]
# Enhancing fine details and improving the overall appearance of images.

# %%
# Enhancing the images
def enhance_image(image_path):
    image = cv2.imread(image_path)
    return cv2.detailEnhance(image, sigma_s=10, sigma_r=0.15)

# %% [markdown]
# Printing one of the images

# %%
import os

# Get the current working directory
current_dir = os.getcwd()

# Define the relative path to the dataset within the GitHub repository
dataset_rel_path = 'chest_xray/train/NORMAL/IM-0115-0001.jpeg'

# Construct the absolute path to the image
image_path = os.path.join(current_dir, dataset_rel_path)

# Define the image enhancement function
def enhance_image(image_path):
    print(f"Loading image from path: {image_path}")
    image = cv2.imread(image_path)
    
    # Check if the image was correctly loaded
    if image is not None:
        enhanced_image = cv2.detailEnhance(image, sigma_s=10, sigma_r=0.15)
        return enhanced_image
    else:
        print(f"Error loading image from path: {image_path}")
        raise FileNotFoundError(f"No image found at {image_path}")

# Try to enhance the image
try:
    enhanced = enhance_image(image_path)
    
    # Convert color from BGR to RGB (OpenCV uses BGR by default)
    enhanced_rgb = cv2.cvtColor(enhanced, cv2.COLOR_BGR2RGB)

    # Display the image
    plt.imshow(enhanced_rgb)
    plt.axis('off')  # Turn off axis numbers
    plt.show()

except FileNotFoundError as e:
    print(e)
# Out:
# Loading image from path: C:\Users\Mollean\Documents\Moringa\Phase_5\Final\Phase-5-Project\chest_xray/train/NORMAL/IM-0115-0001.jpeg

# %% [markdown]
# ### Data Preparation & Pre-processing:
#
# Data augmentation techniques serve the purpose of artificially increasing the diversity of a dataset by applying various transformations to the existing data. In the context of image data, augmentation involves creating new images by making slight modifications to the original ones. The primary purposes of augmentation techniques are: increased diversity, improved robustness, reduced over-fitting, better generalisations and enhanced training efficiency.
#
# Setting 'shuffle=True' for the training generator will randomize the order of our training samples during each epoch. This is beneficial for preventing the model from memorizing the order of the training data and helps improve generalization.

# %%
# Create generator object for train set with shuffle enabled
train_generator = ImageDataGenerator(rescale=1./255,
                                    rotation_range=20,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True
                                     ).flow_from_directory(train_data_folder,
                                                    target_size=(700,700),
                                                    batch_size=32,shuffle=True)

# create geenrator object for val set
val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(val_data_folder, target_size=(700,700),
                                                    batch_size = 32,shuffle=False)

# # create geenrator object for test set
test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(test_data_folder, target_size=(700,700),
                                                    batch_size = 32,shuffle=False)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# Get the value counts for each set
train_value_counts = Counter(train_generator.classes)
val_value_counts = Counter(val_generator.classes)
test_value_counts = Counter(test_generator.classes)

# Display the value counts
print("Train Set Value Counts:")
for class_name, count in train_value_counts.items():
    print(f"{class_name}: {count} images")

print("\nValidation Set Value Counts:")
for class_name, count in val_value_counts.items():
    print(f"{class_name}: {count} images")

print("\nTest Set Value Counts:")
for class_name, count in test_value_counts.items():
    print(f"{class_name}: {count} images")
# Out:
# Train Set Value Counts:
# 0: 1341 images
# 1: 3875 images
#
# Validation Set Value Counts:
# 0: 8 images
# 1: 8 images
#
# Test Set Value Counts:
# 0: 234 images
# 1: 390 images

# %% [markdown]
# The results indicate that the results generated are the same as the original dataset before separating the normal and pneumonia  chest x-rays.

# %% [markdown]
# ### CNN

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

# Define the CNN model
def create_cnn_model(input_shape=(150, 150, 1)):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten the output for the fully connected layers
    model.add(layers.Flatten())

    # Dense (fully connected) layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))  # Adding dropout for regularization

    model.add(layers.Dense(1, activation='sigmoid'))  # Binary classification

    return model

# Create an instance of the model
cnn_model = create_cnn_model()

# Compile the model
cnn_model.compile(optimizer=Adam(lr=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
# Out:
# C:\Users\Mollean\anaconda3\envs\learn-env\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Display the model summary
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense (Dense)               (None, 128)               4735104
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4,827,905
# Trainable params: 4,827,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_validation_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            img_path = os.path.join(path, img)
            img_arr = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img_arr is not None:
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            else:
                print(f"Error loading image: {img_path}")
    return np.array(data, dtype=object)

# %%
from sklearn.utils.class_weight import compute_class_weight

# Assuming 0 is the index for 'NORMAL' and 1 is the index for 'PNEUMONIA'
class_weights = compute_class_weight('balanced', classes=[0, 1], y=train_labels)
class_weight = {0: class_weights[0], 1: class_weights[1]}

# Now you can use class_weight in the fit method
r = cnn_model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(validation_features, validation_labels),
    class_weight=class_weight,
    steps_per_epoch=100,
    validation_steps=25,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-27b019192c49> in <module>
#       6
#       7 # Now you can use class_weight in the fit method
# ----> 8 r = cnn_model.fit(
#       9     train_features,
#      10     train_labels,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\envs\learn-env\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
# Load and preprocess validation data
validation_data = get_validation_data(val_data_folder)

# Assuming your validation data is a tuple of features and labels
validation_features = validation_data[:, 0]  # Assuming the first element is features
validation_labels = validation_data[:, 1]    # Assuming the second element is labels

# Now you can use validation_features and validation_labels in the fit method
r = cnn_model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(validation_features, validation_labels),
    class_weight=class_weight,
    steps_per_epoch=100,
    validation_steps=25,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a5278cac3dae> in <module>
#      12     epochs=10,
#      13     validation_data=(validation_features, validation_labels),
# ---> 14     class_weight=class_weight,
#      15     steps_per_epoch=100,
#      16     validation_steps=25,
#
# NameError: name 'class_weight' is not defined

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Val_Loss')
plt.legend()
plt.title('Loss Evolution')

plt.subplot(2, 2, 2)
plt.plot(r.history['accuracy'], label='Accuracy')
plt.plot(r.history['val_accuracy'], label='Val_Accuracy')
plt.legend()
plt.title('Accuracy Evolution')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-03668c9592e7> in <module>
#       2
#       3 plt.subplot(2, 2, 1)
# ----> 4 plt.plot(r.history['loss'], label='Loss')
#       5 plt.plot(r.history['val_loss'], label='Val_Loss')
#       6 plt.legend()
#
# NameError: name 'r' is not defined

# %%
evaluation = model.evaluate(test)
print(f"Test Accuracy: {evaluation[1] * 100:.2f}%")

evaluation = model.evaluate(train)
print(f"Train Accuracy: {evaluation[1] * 100:.2f}%")

# %%
from sklearn.metrics import confusion_matrix, classification_report

pred = model.predict(test)

print(confusion_matrix(test.classes, pred > 0.5))
pd.DataFrame(classification_report(test.classes, pred > 0.5, output_dict=True))

# %%
pd.DataFrame(classification_report(test.classes, pred > 0.7, output_dict=True))

# %% [markdown]
# ### DenseNet

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, BatchNormalization
from keras.optimizers import Adam
from keras.applications import DenseNet121

# Define input shape and number of classes
input_shape = (150, 150, 3)  # Adjust the dimensions based on your image size and channels
num_classes = 2  # Pneumonia and Normal

# Load DenseNet121 model pre-trained on ImageNet
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=input_shape)

# Create a sequential model
model = Sequential()

# Add the pre-trained base model
model.add(base_model)

# Add additional layers
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Display model summary
model.summary()

# %%
layers = base_model.layers
print(f"The model has {len(layers)} layers")

# %%
print(f"The input shape {base_model.input}")
print(f"The output shape {base_model.output}")

# %%
#model = Sequential()
base_model = DenseNet121(include_top=False, weights='imagenet')
x = base_model.output

x = GlobalAveragePooling2D()(x)

predictions = Dense(1, activation="sigmoid")(x)

model = Model(inputs=base_model.input, outputs=predictions)
#model.add(base_model)
#model.add(GlobalAveragePooling2D())
#model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
r = model.fit(
    train, 
    epochs=10,
    validation_data=validation,
    class_weight=class_weight,
    steps_per_epoch=100,
    validation_steps=25,
)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Val_Loss')
plt.legend()
plt.title('Loss Evolution')

plt.subplot(2, 2, 2)
plt.plot(r.history['accuracy'], label='Accuracy')
plt.plot(r.history['val_accuracy'], label='Val_Accuracy')
plt.legend()
plt.title('Accuracy Evolution')

# %%
evaluation = model.evaluate(test)
print(f"Test Accuracy: {evaluation[1] * 100:.2f}%")

evaluation = model.evaluate(train)
print(f"Train Accuracy: {evaluation[1] * 100:.2f}%")

# %% [markdown]
# ### DenseNet Evaluation

# %%
predicted_vals = model.predict(test, steps=len(test))

# %%
predicted_vals = model.predict(test, steps=len(test))

# %% [markdown]
# ### InceptioNet

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, BatchNormalization
from keras.optimizers import Adam
from keras.applications import InceptionV3

# Define input shape and number of classes
input_shape = (150, 150, 3)  # Adjust the dimensions based on your image size and channels
num_classes = 2  # Pneumonia and Normal

# Load InceptionV3 model pre-trained on ImageNet
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=input_shape)

# Create a sequential model
model = Sequential()

# Add the pre-trained base model
model.add(base_model)

# Add additional layers
model.add(AveragePooling2D(pool_size=(4, 4)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Display model summary
model.summary()

# %%
r = inception_model.fit(train,
          epochs=10,
          validation_data=validation,
          class_weight=class_weight,
          steps_per_epoch=100,
          validation_steps=25)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Val_Loss')
plt.legend()
plt.title('Loss Evolution')

plt.subplot(2, 2, 2)
plt.plot(r.history['accuracy'], label='Accuracy')
plt.plot(r.history['val_accuracy'], label='Val_Accuracy')
plt.legend()
plt.title('Accuracy Evolution')

# %%
evaluation =inception_model.evaluate(test)
print(f"Test Accuracy: {evaluation[1] * 100:.2f}%")

evaluation = inception_model.evaluate(train)
print(f"Train Accuracy: {evaluation[1] * 100:.2f}%")
